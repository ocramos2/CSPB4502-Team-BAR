# %% [markdown]
# ### Import Libraries

# %%
# Source: https://www.kaggle.com/code/denzilseukanundun/notebook4733d8dfd7/notebook

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Read the CSV dataset and view sample records

# %%
data = pd.read_csv('Cleaned_Attributes.csv')
data
# Out:
#              epa       wpa  yards_gained  first_down_pass  complete_pass  \
# 0       2.014474       NaN           0.0              0.0            0.0
# 1       0.077907  0.004655           5.0              0.0            1.0
# 2      -1.402760 -0.040295          -3.0              0.0            0.0
# 3      -1.712583 -0.049576           0.0              0.0            0.0
# 4       2.097796  0.097712           0.0              0.0            0.0
# ...          ...       ...           ...              ...            ...
# 449366 -0.301121 -0.022194           0.0              0.0            0.0
# 449367 -0.320799 -0.042281           5.0              0.0            1.0
# 449368 -0.286672 -0.005457           0.0              0.0            0.0
# 449369       NaN  0.026760          -1.0              0.0            0.0
# 449370       NaN  0.000000           0.0              NaN            NaN
#
#         yards_after_catch  third_down_converted  pass_touchdown  touchdown  \
# 0                     NaN                   0.0             0.0        0.0
# 1                     8.0                   0.0             0.0        0.0
# 2                     NaN                   0.0             0.0        0.0
# 3                     NaN                   0.0             0.0        0.0
# 4                     NaN                   0.0             0.0        0.0
# ...                   ...                   ...             ...        ...
# 449366                NaN                   0.0             0.0        0.0
# 449367                3.0                   0.0             0.0        0.0
# 449368                NaN                   0.0             0.0        0.0
# 449369                NaN                   0.0             0.0        0.0
# 449370                NaN                   NaN             NaN        NaN
#
#         first_down_rush  ydsnet
# 0                   0.0       0
# 1                   0.0       5
# 2                   0.0       2
# 3                   0.0       2
# 4                   0.0       2
# ...                 ...     ...
# 449366              0.0      19
# 449367              0.0      19
# 449368              0.0      19
# 449369              0.0      -1
# 449370              NaN      -1
#
# [449371 rows x 11 columns]

# %% [markdown]
# ### Understand the data

# %% [markdown]
# Let's perform some tasks to understand the data like shape, info, and describe.

# %%
# Shape of our dataset
data.shape
# Out:
# (449371, 11)

# %%
# Info of our dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449371 entries, 0 to 449370
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   epa                   433535 non-null  float64
#  1   wpa                   444050 non-null  float64
#  2   yards_gained          449158 non-null  float64
#  3   first_down_pass       436497 non-null  float64
#  4   complete_pass         436497 non-null  float64
#  5   yards_after_catch     108907 non-null  float64
#  6   third_down_converted  436497 non-null  float64
#  7   pass_touchdown        436497 non-null  float64
#  8   touchdown             436497 non-null  float64
#  9   first_down_rush       436497 non-null  float64
#  10  ydsnet                449371 non-null  int64
# dtypes: float64(10), int64(1)
# memory usage: 37.7 MB

# %%
# Describe our dataset
data.describe()
# Out:
#                  epa            wpa   yards_gained  first_down_pass  \
# count  433535.000000  444050.000000  449158.000000    436497.000000
# mean        0.008488       0.001968       3.903698         0.139025
# std         1.327887       0.045293       7.884118         0.345973
# min       -12.849594      -0.997214     -38.000000         0.000000
# 25%        -0.611316      -0.014464       0.000000         0.000000
# 50%        -0.030269       0.000000       0.000000         0.000000
# 75%         0.571199       0.014409       6.000000         0.000000
# max         9.508015       0.994848      99.000000         1.000000
#
#        complete_pass  yards_after_catch  third_down_converted  pass_touchdown  \
# count  436497.000000      108907.000000         436497.000000   436497.000000
# mean        0.249828           5.216919              0.059893        0.017721
# std         0.432914           7.230935              0.237288        0.131934
# min         0.000000         -81.000000              0.000000        0.000000
# 25%         0.000000           1.000000              0.000000        0.000000
# 50%         0.000000           3.000000              0.000000        0.000000
# 75%         0.000000           7.000000              0.000000        0.000000
# max         1.000000          90.000000              1.000000        1.000000
#
#            touchdown  first_down_rush         ydsnet
# count  436497.000000    436497.000000  449371.000000
# mean        0.029400         0.069391      27.369207
# std         0.168925         0.254118      25.617677
# min         0.000000         0.000000     -87.000000
# 25%         0.000000         0.000000       5.000000
# 50%         0.000000         0.000000      21.000000
# 75%         0.000000         0.000000      46.000000
# max         1.000000         1.000000      99.000000

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# We will now use matplotlib and seaborn library.
# We will show the correlation of the both columns

# %%
# Using pairplot we'll visualize the data for correlation
sns.pairplot(data, x_vars=['epa'], 
             y_vars='epa', size=4, aspect=1, kind='scatter')
plt.show()

sns.pairplot(data, x_vars=['epa'], 
             y_vars='wpa', size=4, aspect=1, kind='scatter')
plt.show()

sns.pairplot(data, x_vars=['epa'], 
             y_vars='yards_gained', size=4, aspect=1, kind='scatter')
plt.show()

sns.pairplot(data, x_vars=['epa'], 
             y_vars='first_down_pass', size=4, aspect=1, kind='scatter')
plt.show()

sns.pairplot(data, x_vars=['epa'], 
             y_vars='complete_pass', size=4, aspect=1, kind='scatter')
plt.show()

sns.pairplot(data, x_vars=['epa'], 
             y_vars='yards_after_catch', size=4, aspect=1, kind='scatter')
plt.show()

sns.pairplot(data, x_vars=['epa'], 
             y_vars='third_down_converted', size=4, aspect=1, kind='scatter')
plt.show()

sns.pairplot(data, x_vars=['epa'], 
             y_vars='pass_touchdown', size=4, aspect=1, kind='scatter')
plt.show()

sns.pairplot(data, x_vars=['epa'], 
             y_vars='touchdown', size=4, aspect=1, kind='scatter')
plt.show()

sns.pairplot(data, x_vars=['epa'], 
             y_vars='first_down_rush', size=4, aspect=1, kind='scatter')
plt.show()

sns.pairplot(data, x_vars=['epa'], 
             y_vars='ydsnet', size=4, aspect=1, kind='scatter')
plt.show()

# %% [markdown]
# If we cannot determine the correlation using a scatter plot, we can use the seaborn heatmap to visualize the data.

# %%
# Using the heatmap to visualize 
sns.heatmap(data.corr(), cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
# ### Performing Simple Linear Regression

# %% [markdown]
# #### Create X and y

# %% [markdown]
# Linear Regression is performed in the following steps:
# 1. Create X and y
# 2. Create Train and Test set
# 3. Train your model
# 4. Evaluate the model

# %%
# Creating X and y
X = data['wpa'].fillna(0)
y = data['epa'].fillna(0)

y
# Out:
# 0         2.014474
# 1         0.077907
# 2        -1.402760
# 3        -1.712583
# 4         2.097796
#             ...
# 449366   -0.301121
# 449367   -0.320799
# 449368   -0.286672
# 449369    0.000000
# 449370    0.000000
# Name: epa, Length: 449371, dtype: float64

# %% [markdown]
# #### Create Train and Test sets

# %% [markdown]
# We’ll divide the training and testing sets into a 9:1 ratio, respectively.

# %%
X
# Out:
# 0         0.000000
# 1         0.004655
# 2        -0.040295
# 3        -0.049576
# 4         0.097712
#             ...
# 449366   -0.022194
# 449367   -0.042281
# 449368   -0.005457
# 449369    0.026760
# 449370    0.000000
# Name: wpa, Length: 449371, dtype: float64

# %% [markdown]
# We’ll split the data by importing train_test_split from the sklearn.model_selection library.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.9,
                                                    test_size = 0.1, random_state = 100)

# %%
#Take a look at the train dataset
X_train
# Out:
# 434076   -0.012616
# 253612    0.000000
# 83817    -0.023904
# 236616    0.003754
# 148574    0.011638
#             ...
# 339799    0.009269
# 253799   -0.051101
# 210755    0.019416
# 56088    -0.004089
# 300552   -0.006746
# Name: wpa, Length: 404433, dtype: float64

# %%
y_train
# Out:
# 434076   -1.290704
# 253612    0.000000
# 83817    -0.651277
# 236616    0.096851
# 148574    0.763982
#             ...
# 339799    2.208471
# 253799   -1.752942
# 210755    0.852430
# 56088    -0.263548
# 300552   -0.464718
# Name: epa, Length: 404433, dtype: float64

# %% [markdown]
# #### Building and training the model

# %% [markdown]
# Using the following two packages, we can build a simple linear regression model.
# * statsmodel
# * sklearn

# %%
import statsmodels.api as sm

# %%
# Adding a constant to get an intercept
X_train_sm = sm.add_constant(X_train)

# %% [markdown]
# Once we’ve added constant, we can fit the regression line using **OLS** (Ordinary Least Square) method present in the **statsmodel**. After that, we’ll see the parameters, i.e., c and m of the straight line.

# %%
# Fitting the regession line using 'OLS'
lr = sm.OLS(y_train, X_train_sm).fit()

# Printing the parameters
leastRegressionParams = lr.params.values

# %%
# Performing a summary to list out all the different parameters of the regression line fitted
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    epa   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                 4.991e+05
# Date:                Thu, 21 Apr 2022   Prob (F-statistic):               0.00
# Time:                        21:20:54   Log-Likelihood:            -5.1943e+05
# No. Observations:              404433   AIC:                         1.039e+06
# Df Residuals:                  404431   BIC:                         1.039e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0342      0.001    -24.836      0.000      -0.037      -0.031
# wpa           21.5802      0.031    706.452      0.000      21.520      21.640
# ==============================================================================
# Omnibus:                   163884.953   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        114891891.538
# Skew:                           0.456   Prob(JB):                         0.00
# Kurtosis:                      85.566   Cond. No.                         22.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# We have to make sure that the p-value should always be less for the coefficient to be significant

# %%
# Visualizing the regression line
plt.scatter(X_train, y_train)

# X_train, const/coeff + wpa * X_train, 'r'
plt.plot(X_train, leastRegressionParams[0] + leastRegressionParams[1] * X_train, 'r')
plt.show()

# %% [markdown]
# #### Residual Analysis

# %% [markdown]
# Error = Actual y value - y predicted value

# %%
# Predicting y_value using training data of X
y_train_pred = lr.predict(X_train_sm)

# Creating residuals from the y_train data and predicted y_data
result = (y_train - y_train_pred)

# %% [markdown]
# Now, let’s plot the histogram of the residuals and see whether it looks like normal distribution or not.

# %%
# Plotting the histogram using the residual values
fig = plt.figure()
sns.distplot(result, bins = 15)
plt.title('Error Terms', fontsize = 15)
plt.xlabel('y_train - y_train_pred', fontsize = 15)
plt.show()

# %% [markdown]
# Now, make sure that the residuals are not following any specific pattern.

# %%
# Looking for any patterns in the residuals
plt.scatter(X_train,result)
plt.show()

# %% [markdown]
# Since the Residuals follow a normal distribution and do not follow any specific pattern, we can use the linear regression model we have built to evaluate test data.

# %% [markdown]
# #### Predictions on the Test data or Evaluating the model

# %% [markdown]
# Now that we have fitted the regression line on our train dataset, we can make some predictions to the test data. Similar to the training dataset, we have to **add_constant** to the test data and predict the y values using the **predict** attribute present in the **statsmodel**.

# %%
# Adding a constant to X_test
X_test_sm = sm.add_constant(X_test)

# Predicting the y values corresponding to X_test_sm
y_test_pred = lr.predict(X_test_sm)

# Printing the first 15 predicted values
y_test_pred
# Out:
# 388523   -1.492773
# 181005   -0.684039
# 61134    -0.194168
# 336732   -1.244834
# 438037    0.515576
#             ...
# 271152   -0.173234
# 262077    1.826898
# 165148   -0.293324
# 92883    -0.431438
# 288356   -0.077927
# Length: 44938, dtype: float64

# %% [markdown]
# Now, let’s calculate the **R²** value for the above-predicted y-values. We can do that by merely importing the **r2_score** library from **sklearn.metrics** package.

# %%
# Importing r2_square
from sklearn.metrics import r2_score

# Checking the R-squared value
r_squared = r2_score(y_test, y_test_pred)
r_squared
# Out:
# 0.5180192707643312

# %% [markdown]
# Since the R² value on test data is within 5% of the R² value on training data, we can conclude that the model is pretty stable. Which means, what the model has learned on the training set can generalize on the unseen test set.

# %% [markdown]
# Let’s visualize the line on the test data.

# %%
# Visualize the line on the test set
plt.scatter(X_test, y_test)
plt.plot(X_test, y_test_pred, 'r')
plt.show()
